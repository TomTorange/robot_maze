# %% [markdown]
# # Section 0 问题描述与完成项目流程
#
# ## 1. 问题描述
#
#
# <img src="default.png" width="20%"></img>
#
# 在该项目中，你将使用强化学习算法，实现一个自动走迷宫机器人。
#
# 1. 如上图所示，智能机器人显示在右上角。在我们的迷宫中，有陷阱（红色炸弹）及终点（蓝色的目标点）两种情景。机器人要尽量避开陷阱、尽快到达目的地。
# 2. 小车可执行的动作包括：向上走 `u`、向右走 `r`、向下走 `d`、向左走 `l`。
# 3. 执行不同的动作后，根据不同的情况会获得不同的奖励，具体而言，有以下几种情况。
#     - 撞到墙壁：-10
#     - 走到终点：50
#     - 走到陷阱：-30
#     - 其余情况：-0.1
# 4. 我们需要通过修改 `robot.py` 中的代码，来实现一个 Q Learning 机器人，实现上述的目标。
#
# ## 2. 完成项目流程
#
# 1. 配置环境，使用 `envirnment.yml` 文件配置名为 `robot-env` 的 conda 环境，具体而言，你只需转到当前的目录，在命令行/终端中运行如下代码，稍作等待即可。
# ```
# conda env create -f envirnment.yml
# ```
# 安装完毕后，在命令行/终端中运行 `source activate robot-env`（Mac/Linux 系统）或 `activate robot-env`（Windows 系统）激活该环境。
#
# 2. 阅读 `main.ipynb` 中的指导完成项目，并根据指导修改对应的代码，生成、观察结果。
# 3. 导出代码与报告，上传文件，提交审阅并优化。
# ---
#
# ---

# %% [markdown]
# # Section 1 算法理解

# %% [markdown]
# ## 1. 1 强化学习总览
#
# 强化学习作为机器学习算法的一种，其模式也是让智能体在“训练”中学到“经验”，以实现给定的任务。但不同于监督学习与非监督学习，在强化学习的框架中，我们更侧重通过智能体与环境的**交互**来学习。通常在监督学习和非监督学习任务中，智能体往往需要通过给定的训练集，辅之以既定的训练目标（如最小化损失函数），通过给定的学习算法来实现这一目标。然而在强化学习中，智能体则是通过其与环境交互得到的奖励进行学习。这个环境可以是虚拟的（如虚拟的迷宫），也可以是真实的（自动驾驶汽车在真实道路上收集数据）。
#
#
# 在强化学习中有五个核心组成部分，它们分别是：**环境（Environment）**、**智能体（Agent）**、**状态（State）**、**动作（Action）**和**奖励（Reward）**。在某一时间节点 $t$：
#
# - 智能体在从环境中感知其所处的状态 $s_t$
# - 智能体根据某些准则选择动作 $a_t$
# - 环境根据智能体选择的动作，向智能体反馈奖励 $r_{t+1}$
#
# 通过合理的学习算法，智能体将在这样的问题设置下，成功学到一个在状态 $s_t$ 选择动作 $a_t$ 的策略 $\pi (s_t) = a_t$。

# %% [markdown]
# ---
#
# **问题 1**：请参照如上的定义，描述出 “机器人走迷宫这个问题” 中强化学习五个组成部分对应的实际对象：
#
# - **环境** : 二维迷宫
# - **状态** : 即智能机器人所处的迷宫坐标位置，这里通过二维坐标 (0,1)、(1,1) 等表示。初始设置中，终点、陷阱等等有一个初始二维坐标。
#
#
# - **动作** : 向上走 `u`、向右走 `r`、向下走 `d`、向左走 `l`
# - **奖励** : 撞到墙壁：-10， 走到陷阱：-30， 走到终点：50，其余情况：-0.1
#
# $$T(s^{'}, a, s) = P(s^{'}|a,s)$$
#
#
# ---

# %% [markdown]
# ## 1.2 计算 Q 值
#
# 在我们的项目中，我们要实现基于 Q-Learning 的强化学习算法。Q-Learning 是一个值迭代（Value Iteration）算法。与策略迭代（Policy Iteration）算法不同，值迭代算法会计算每个”状态“或是”状态-动作“的值（Value）或是效用（Utility），然后在执行动作的时候，会设法最大化这个值。因此，对每个状态值的准确估计，是我们值迭代算法的核心。通常我们会考虑**最大化动作的长期奖励**，即不仅考虑当前动作带来的奖励，还会考虑动作长远的奖励。
#
# 在 Q-Learning 算法中，我们把这个长期奖励记为 Q 值，我们会考虑每个 ”状态-动作“ 的 Q 值，具体而言，它的计算公式为：
#
# $$
# q(s_{t},a) = R_{t+1} + \gamma \times\max_a q(a,s_{t+1})
# $$
#
# 也就是对于当前的“状态-动作” $(s_{t},a)$，我们考虑执行动作 $a$ 后环境给我们的奖励 $R_{t+1}$，以及执行动作 $a$ 到达 $s_{t+1}$后，执行任意动作能够获得的最大的Q值 $\max_a q(a,s_{t+1})$，$\gamma$ 为折扣因子。
#
# 不过一般地，我们使用更为保守地更新 Q 表的方法，即引入松弛变量 $alpha$，按如下的公式进行更新，使得 Q 表的迭代变化更为平缓。
#
# $$
# q(s_{t},a) = (1-\alpha) \times q(s_{t},a) + \alpha \times(R_{t+1} + \gamma \times\max_a q(a,s_{t+1}))
# $$

# %% [markdown]
# ---
# <img src="default2.png" width="20%"></img>
#
# **问题 2**：根据已知条件求 $q(s_{t},a)$，在如下模板代码中的空格填入对应的数字即可。
#
#
# 已知：如上图，机器人位于 $s_1$，行动为 `u`，行动获得的奖励与题目的默认设置相同。在 $s_2$ 中执行各动作的 Q 值为：`u`: -24，`r`: -13，`d`: -0.29、`l`: +40，$\gamma$ 取0.9。
#
#
# $$
# \begin{align}
# q(s_{t},a) & = R_{t+1} + \gamma \times\max_a q(a,s_{t+1}) \\
#  & =(-0.1) + (0.9)*(40) \\
#  & =35.9
# \end{align}
# $$
#
#
# ---

# %% [markdown]
# ## 1.3 如何选择动作
#
# 在强化学习中，「探索-利用」问题是非常重要的问题。具体来说，根据上面的定义，我们会尽可能地让机器人在每次选择最优的决策，来最大化长期奖励。但是这样做有如下的弊端：
# 1. 在初步的学习中，我们的 Q 值会不准确，如果在这个时候都按照 Q 值来选择，那么会造成错误。
# 2. 学习一段时间后，机器人的路线会相对固定，则机器人无法对环境进行有效的探索。
#
# 因此我们需要一种办法，来解决如上的问题，增加机器人的探索。由此我们考虑使用 epsilon-greedy 算法，即在小车选择动作的时候，以一部分的概率随机选择动作，以一部分的概率按照最优的 Q 值选择动作。同时，这个选择随机动作的概率应当随着训练的过程逐步减小。

# %% [markdown]
# ---
#
# **问题 3**：在如下的代码块中，实现 epsilon-greedy 算法的逻辑，并运行测试代码。

# %%
import random
import numpy as np
actions = ['u','r','d','l']
qline = {'u':1.2, 'r':-2.1, 'd':-24.5, 'l':27}
epsilon = 0.3 # 以0.3的概率进行随机选择

def choose_action(epsilon):
    
    action = None
    if random.random() < epsilon: # 以某一概率
        action = random.choice(actions) # 实现对动作的随机选择
    else:             # epsilon belong to 0.3 ~ 1;
        action = max(qline, key=qline.get)  # 否则选择具有最大 Q 值的动作
    return action

# %%
choose_action(epsilon)
# Out:
# 'd'

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# # Section 2 代码实现
#
# ## 2.1. `Maze` 类理解

# %% [markdown]
# 我们首先引入了迷宫类 `Maze`，这是一个非常强大的函数，它能够根据你的要求随机创建一个迷宫，或者根据指定的文件，读入一个迷宫地图信息。
#
# 1. 使用 `Maze("file_name")` 根据指定文件创建迷宫，或者使用 `Maze(maze_size=(height,width))` 来随机生成一个迷宫。
# 2. 使用 `trap_number` 参数，在创建迷宫的时候，设定迷宫中陷阱的数量。
# 3. 直接键入迷宫变量的名字按回车，展示迷宫图像（如 `g=Maze("xx.txt")`，那么直接输入 `g` 即可。
# 4. 建议生成的迷宫尺寸，长在 6~12 之间，宽在 10～12 之间。

# %% [markdown]
# ---
#
# **问题 4**：在如下的代码块中，创建你的迷宫并展示。

# %%
from Maze import Maze
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

## todo: 创建迷宫并展示
robot_maze=Maze(maze_size=(10,11), trap_number=6)
robot_maze
# Out:
# Maze of size (10, 11)

# %% [markdown]
# ---
#
# 你可能已经注意到，在迷宫中我们已经默认放置了一个机器人。实际上，我们为迷宫配置了相应的 API，来帮助机器人的移动与感知。其中你随后会使用的两个 API 为 `maze.sense_robot()` 及 `maze.move_robot()`。
#
# 1. `maze.sense_robot()` 为一个无参数的函数，输出机器人在迷宫中目前的位置。
# 2. `maze.move_robot(direction)` 对输入的移动方向，移动机器人，并返回对应动作的奖励值。
#
# ---
#
# **问题 5**：随机移动机器人，并记录下获得的奖励，展示出机器人最后的位置。

# %%
rewards = []
actions = ['u','r','d','l']

## 循环、随机移动机器人10次，记录下奖励
for i in range(10):
    current_reward = robot_maze.move_robot(random.choice(actions))
    rewards.append(current_reward)

## 输出机器人最后的位置
print(rewards)
print("the last position of robot is",robot_maze.sense_robot())

## 打印迷宫，观察机器人位置
print(robot_maze)
# Out:
# [-0.1, -10.0, -10.0, -10.0, -0.1, -0.1, -0.1, -30.0, -10.0, -0.1]
# the last position of robot is (4, 10)
# Maze of size (10, 11)

# %% [markdown]
# ## 2.2. `Robot` 类实现

# %% [markdown]
# `Robot` 类是我们需要重点实现的部分。在这个类中，我们需要实现诸多功能，以使得我们成功实现一个强化学习智能体。总体来说，之前我们是人为地在环境中移动了机器人，但是现在通过实现 `Robot` 这个类，机器人将会自己移动。通过实现学习函数，`Robot` 类将会学习到如何选择最优的动作，并且更新强化学习中对应的参数。
#
# 首先 `Robot` 有多个输入，其中 `alpha=0.5, gamma=0.9, epsilon0=0.5` 表征强化学习相关的各个参数的默认值，这些在之前你已经了解到，`Maze` 应为机器人所在迷宫对象。
#
# 随后观察 `Robot.update` 函数，它指明了在每次执行动作时，`Robot` 需要执行的程序。按照这些程序，各个函数的功能也就明了了。
#
# 最后你需要实现 `Robot.py` 代码中的8段代码，他们都在代码中以 `#TODO` 进行标注，你能轻松地找到他们。

# %% [markdown]
# ---
#
# **问题 6**：实现 `Robot.py` 中的8段代码，并运行如下代码检查效果（记得将 `maze` 变量修改为你创建迷宫的变量名）。

# %%
from Robot import Robot
robot = Robot(robot_maze) # 记得将 maze 变量修改为你创建迷宫的变量名
robot.set_status(learning=True,testing=False)
print(robot.update())

robot_maze
# Out:
# ('r', -10.0)
# Maze of size (10, 11)

# %% [markdown]
# ---

# %% [markdown]
# ## 2.3 用 `Runner` 类训练 Robot
#
# 在实现了上述内容之后，我们就可以开始对我们 `Robot` 进行训练并调参了。我们为你准备了又一个非常棒的类 `Runner`，来实现整个训练过程及可视化。使用如下的代码，你可以成功对机器人进行训练。并且你会在当前文件夹中生成一个名为 `filename` 的视频，记录了整个训练的过程。通过观察该视频，你能够发现训练过程中的问题，并且优化你的代码及参数。
#
# ---
#
# **问题 7**：尝试利用下列代码训练机器人，并进行调参。可选的参数包括：
#
# - 训练参数
#     - 训练次数 `epoch`
# - 机器人参数：
#     - `epsilon0` (epsilon 初值)
#     - `epsilon`衰减（可以是线性、指数衰减，可以调整衰减的速度），你需要在 Robot.py 中调整
#     - `alpha`
#     - `gamma`
# - 迷宫参数:
#     - 迷宫大小
#     - 迷宫中陷阱的数量

# %%
## 可选的参数(0)：
epoch = 20

epsilon0 = 0.5
alpha = 0.5
gamma = 0.9

maze_size = (6,6)
trap_number = 1

# %%
from Runner import Runner

g = Maze(maze_size=maze_size,trap_number=trap_number)
r = Robot(g,alpha=alpha, epsilon0=epsilon0, gamma=gamma)
r.set_status(learning=True)

runner = Runner(r, g)
runner.run_training(epoch, display_direction=True)
# runner.generate_movie(filename = "final.mp4") # 你可以注释该行代码，加快运行速度，不过你就无法观察到视频了。

# %%
runner.plot_results()

# %% [markdown]
# ---
#
# 使用 `runner.plot_results()` 函数，能够打印机器人在训练过程中的一些参数信息。
#
# - Success Times 代表机器人在训练过程中成功的累计次数，这应当是一个累积递增的图像。
# - Accumulated Rewards 代表机器人在每次训练 epoch 中，获得的累积奖励的值，这应当是一个逐步递增的图像。
# - Running Times per Epoch 代表在每次训练 epoch 中，小车训练的次数（到达终点就会停止该 epoch 转入下次训练），这应当是一个逐步递减的图像。
#
# ---
#
# **问题 8**：使用 `runner.plot_results()` 输出训练结果，根据该结果对你的机器人进行分析。
#
# - 指出你选用的参数如何，选用参数的原因。
# - 建议你比较不同参数下机器人的训练的情况。
# - 训练的结果是否满意，有何改进的计划。

# %%
## 可选的参数(1)：(only change epoch)
epoch = 6
epsilon0 = 0.5
alpha = 0.5
gamma = 0.9
maze_size = (10,11)
trap_number = 1
g2 = Maze(maze_size=maze_size,trap_number=trap_number)
r2 = Robot(g2,alpha=alpha, epsilon0=epsilon0, gamma=gamma)
r2.set_status(learning=True)
runner = Runner(r2, g2)
runner.run_training(epoch, display_direction=True)
# runner.generate_movie(filename = "final2.mp4") # 你可以注释该行代码，加快运行速度，不过你就无法观察到视频了。
runner.plot_results()

# %%
## 可选的参数(2)：(only change epsilon0)
epoch = 20
epsilon0 = 0.9   #compare epsilon0
alpha = 0.5
gamma = 0.9
maze_size = (10,11)
trap_number = 1
g2 = Maze(maze_size=maze_size,trap_number=trap_number)
r2 = Robot(g2,alpha=alpha, epsilon0=epsilon0, gamma=gamma)
r2.set_status(learning=True)
runner = Runner(r2, g2)
runner.run_training(epoch, display_direction=True)
# runner.generate_movie(filename = "final2.mp4") # 你可以注释该行代码，加快运行速度，不过你就无法观察到视频了。
runner.plot_results()

# %%
## 可选的参数(3)：(only change epsilon0)
epoch = 20
epsilon0 = 0.1   #compare
alpha = 0.5     
gamma = 0.9
maze_size = (10,11)
trap_number = 1
g3 = Maze(maze_size=maze_size,trap_number=trap_number)
r3 = Robot(g3,alpha=alpha, epsilon0=epsilon0, gamma=gamma)
r3.set_status(learning=True)
runner = Runner(r3, g3)
runner.run_training(epoch, display_direction=True)
# runner.generate_movie(filename = "final3.mp4") # 你可以注释该行代码，加快运行速度，不过你就无法观察到视频了。
runner.plot_results()

# %%
## 可选的参数(4)：(only change alpha)
epoch = 20
epsilon0 = 0.5   
alpha = 0.1      #compare
gamma = 0.9     
maze_size = (10,11)
trap_number = 1
g4 = Maze(maze_size=maze_size,trap_number=trap_number)
r4 = Robot(g4,alpha=alpha, epsilon0=epsilon0, gamma=gamma)
r4.set_status(learning=True)
runner = Runner(r4, g4)
runner.run_training(epoch, display_direction=True)
# runner.generate_movie(filename = "final4.mp4") # 你可以注释该行代码，加快运行速度，不过你就无法观察到视频了。
runner.plot_results()

# %%
## 可选的参数(5)：(only change alpha)
epoch = 20
epsilon0 = 0.5
alpha = 0.9      #compare
gamma = 0.9      
maze_size = (10,11)
trap_number = 1
g5 = Maze(maze_size=maze_size,trap_number=trap_number)
r5 = Robot(g5,alpha=alpha, epsilon0=epsilon0, gamma=gamma)
r5.set_status(learning=True)
runner = Runner(r5, g5)
runner.run_training(epoch, display_direction=True)
# runner.generate_movie(filename = "final5.mp4") # 你可以注释该行代码，加快运行速度，不过你就无法观察到视频了。
runner.plot_results()

# %%
## 可选的参数(6)：(only change gamma)
epoch = 20
epsilon0 = 0.5
alpha = 0.5
gamma = 0.1     # compare
maze_size = (10,11)
trap_number = 1
g6 = Maze(maze_size=maze_size,trap_number=trap_number)
r6 = Robot(g6,alpha=alpha, epsilon0=epsilon0, gamma=gamma)
r6.set_status(learning=True)
runner = Runner(r6, g6)
runner.run_training(epoch, display_direction=True)
# runner.generate_movie(filename = "final6.mp4") # 你可以注释该行代码，加快运行速度，不过你就无法观察到视频了。
runner.plot_results()

# %%
## 可选的参数(7)：(only change trap_number)
epoch = 20
epsilon0 = 0.5
alpha = 0.5
gamma = 0.9
maze_size = (10,11)
trap_number = 9    # compare, trap_number = 10 will never success
g7 = Maze(maze_size=maze_size,trap_number=trap_number)
r7 = Robot(g7,alpha=alpha, epsilon0=epsilon0, gamma=gamma)
r7.set_status(learning=True)
runner = Runner(r7, g7)
runner.run_training(epoch, display_direction=True)
# runner.generate_movie(filename = "final7.mp4") # 你可以注释该行代码，加快运行速度，不过你就无法观察到视频了。
runner.plot_results()

# %%
## 个人优化的参数(8)：(All)
epoch = 20
epsilon0 = 0.1
alpha = 0.5
gamma = 0.9
maze_size = (10,11)
trap_number = 4    # compare, trap_number = 10 will never success
g8 = Maze(maze_size=maze_size,trap_number=trap_number)
r8 = Robot(g8,alpha=alpha, epsilon0=epsilon0, gamma=gamma)
r8.set_status(learning=True)
runner = Runner(r8, g8)
runner.run_training(epoch, display_direction=True)
# runner.generate_movie(filename = "final8.mp4") # 你可以注释该行代码，加快运行速度，不过你就无法观察到视频了。
runner.plot_results()

# %% [markdown]
# 回答：
# 1. epoch： 训练次数：如果训练次数很少，例如低于5将很难达到目标，建议增加训练次数。但在结果收敛情况下再增加epoch就没有意义了。
# 2. gamma： discount rate (0,1)：用来折扣汇报G，我们将更改目标去关心更近期的奖励，而不是遥远未来获得的奖励。（更早发生的奖励始终乘以更大的数字），这个gamma不是智能体学习获得，是人为设置来优化robot的目标。gamma越大，对未来关注越高；gamma越小，折扣越高，极端情况下，只关注最近的奖励。通常设置为0.9，否则robot就会出现看不清故障的情况。如果这个值大于1，那么实际上未来奖励会发散开来（因为这是一个不断累加、迭代的过程），导致Qtable不能发散。它能够帮助终点处的正奖励“扩散”到周围，也就是说，这样机器人更能够成功地学习到通往终点的路径。
# 3. alpha：权衡上一次学习结果和这次学习结果的值。当alpha设置为1，新的估值是目标，我们完全忽略并替换之前的估值。当alpha设置为0，则完全忽略目标，并保留旧的估值。但这样robot将学不到新知识。通常，alpha越小，我们在进行更新时对目标的信任就越低。由于alpha设置过低会导致机器人只在乎现有和之前的知识，而不能积累新的 reward，所以又不能设置太小。
# 4. epsilon0：采用epsilon，随机选择一个动作。采用1-epsilon，选择贪婪动作。epsilon是个0~1之间的小数，数越小，越接近于贪婪策略，robot胆子越大，越勇敢，不怕遇到trap炸弹。例如，一开始，epsilon采取大的数，例如1，可以小心翼翼的随机动作，由于对环境越来越有把握，后来可采取一个小的epsilon小数，勇敢的继续大范围探索。
# 5. maze size: 迷宫大小越大越复杂，越小越简单容易达到目标，但如果太小的迷宫又trap阻挡，也可能永远不能sucess。
# 6. trap number：trap陷阱越多越不容易达到目标。

# %% [markdown]
# 回答：以上8种情况对不同参数进行了对比。第1种比较了小的epoch，太小的epoch不能达到目标, epoch小于5的时候，success time基本是直线。
# 第2种，第3种，epsilon分别为0.9和0.1时候，看出0.9时候，收敛很慢，Running Times per Epoch不容易做到逐步降低，总是在小心的探索。第4第5种分别为0.1和0.9的情况，可以看出alpha=0.1非常保守，经过很长时间才能达到success。第6种gamma设置一个很小的值，robot不容易学习到一个到终点的策略，收敛很慢，Running Times per Epoch很难降低。
# 第7种设置了多个trap增加了robot探索的难度，导致不能成功走出迷宫。

# %% [markdown]
# 回答：第8种根据前7种情况对比进行的分析，选取了适当合适的数值，对训练结果基本满意。
# 如果改进，由于学习率 α 的目的是为了在更新 Q 值的同时也保留过去学到的结果，那么对于不同的 state，实际上学习的进度是不一样的。那么此处对所有的 state 统一设置 α，似乎并不是最优的做法。可以考虑对每个 state 设置不同的学习率，该 state 学习完毕后其对应的 α 衰减，而其他 state 对应的 α 不变。

# %% [markdown]
# ---
#
# **问题 9：** 请将如下的文件打包，提交文件给审阅者。
#
# - `robot.py`
# - `robot_maze.ipynb`
# - 由 `robot_maze.ipynb` 导出的 `robot_maze.html`
